# %%
from homework import utils
from torchvision.transforms import ToPILImage

train_ds = utils.VehicleClassificationDataset("VehicleClassificationDataset/train_subset")
print(len(train_ds))
i = 401
print(train_ds[i][1])
ToPILImage()(train_ds[i][0])
# Out:
# 1909
# 2
# <PIL.Image.Image image mode=RGB size=276x203>

# %%
from torchvision import models
# Out:
# relu <class 'torch.nn.modules.activation.ReLU'>
# layer1.0.relu <class 'torch.nn.modules.activation.ReLU'>
# layer1.1.relu <class 'torch.nn.modules.activation.ReLU'>
# layer1.2.relu <class 'torch.nn.modules.activation.ReLU'>
# layer2.0.relu <class 'torch.nn.modules.activation.ReLU'>
# layer2.1.relu <class 'torch.nn.modules.activation.ReLU'>
# layer2.2.relu <class 'torch.nn.modules.activation.ReLU'>
# layer2.3.relu <class 'torch.nn.modules.activation.ReLU'>
# layer3.0.relu <class 'torch.nn.modules.activation.ReLU'>
# layer3.1.relu <class 'torch.nn.modules.activation.ReLU'>
# layer3.2.relu <class 'torch.nn.modules.activation.ReLU'>
# layer3.3.relu <class 'torch.nn.modules.activation.ReLU'>
# layer3.4.relu <class 'torch.nn.modules.activation.ReLU'>
# layer3.5.relu <class 'torch.nn.modules.activation.ReLU'>
# layer4.0.relu <class 'torch.nn.modules.activation.ReLU'>
# layer4.1.relu <class 'torch.nn.modules.activation.ReLU'>
# layer4.2.relu <class 'torch.nn.modules.activation.ReLU'>
